# %% [markdown]
# # Plot Trajectories
#
# Plotting various trajecories to demonstrate the difference between PID, RL trained in 1 direction, and RL trained on 4 directions of wind. See other notebooks, such as `Demo.ipynb` for more details about some of these functions.

# %%
from systems.long_multirotor import LongTrajEnv

from typing import Union, Iterable, List
from copy import deepcopy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from tqdm.autonotebook import tqdm, trange
import optuna

from rl import learn_rl, transform_rl_policy, evaluate_rl, PPO, load_agent
from multirotor.simulation import Multirotor
from multirotor.helpers import DataLog
from multirotor.visualize import plot_datalog
from multirotor.controller import Controller
from multirotor.trajectories import Trajectory, GuidedTrajectory
from multirotor.controller.scurves import SCurveController
from systems.multirotor import MultirotorTrajEnv, VP
from multirotor.controller import (
    AltController, AltRateController,
    PosController, AttController,
    VelController, RateController,
    Controller
)
from scripts.opt_pidcontroller import (
    get_controller, make_disturbance_fn,
    apply_params as apply_params_pid, get_study as get_study_pid
)
from scripts.opt_multirotorenv import apply_params, get_study, get_established_controller
import pickle

# %%
log_root_path = './tensorboard/MultirotorTrajEnv/optstudy/%s/'
def get_study_agent_params(name, overwrite_trial=None):
    study = get_study(name)
    best_trial = study.best_trial.number
    if overwrite_trial is not None:
        best_trial=overwrite_trial
    best_agent = load_agent((log_root_path + '%03d/run_1/agent') % (name, best_trial))
    best_params = study.best_params
    return study, best_agent, best_params

# %%
def get_established_controller(m: Multirotor):
    ctrl = get_controller(m, scurve=False)

    with open('./params/manual_pid.pkl', 'rb') as f: #TODO: make relative
        optimal_params = pickle.load(f)

    optimal_params['ctrl_z']['k_p'] = np.array([0.4])
    optimal_params['ctrl_z']['k_i'] = np.array([0.0])
    optimal_params['ctrl_z']['k_d'] = np.array([0.0])
    optimal_params['ctrl_p']['max_velocity'] = 15

    z_params = optimal_params['ctrl_z']
    optimal_params['ctrl_vz']['k_p'] = 25
    vz_params = optimal_params['ctrl_vz']

    ctrl.set_params(**optimal_params)
    ctrl.ctrl_z.set_params(**z_params)
    ctrl.ctrl_vz.set_params(**vz_params)
    return ctrl

# %%
def get_env(wind_ranges, scurve=False, **kwargs):  
    kw = dict(
        safety_radius=kwargs['safety_radius'],
        vp=VP,get_controller_fn=lambda m: get_established_controller(m),
        steps_u=kwargs['steps_u'],
        scaling_factor=kwargs['scaling_factor'],
        wind_ranges=wind_ranges,
        proximity=5, 
        seed=kwargs['seed'])
    return MultirotorTrajEnv(**kw)

# %%
def get_long_env(best_params, wind_range):
    env_kwargs = dict(
        safety_corridor=5,
        safety_radius=5,
        seed=0,
        get_controller_fn=lambda m: get_established_controller(m),
        vp = VP,
    )

    env_kwargs['steps_u'] = best_params['steps_u']
    env_kwargs['scaling_factor'] = best_params['scaling_factor']

    square_np = np.array([[100,0,0], [100,100,0], [0,100,0], [0,0,0]])
    square_traj = Trajectory(None, points=square_np, resolution=best_params['bounding_rect_length']) 
    square_wpts = square_traj.generate_trajectory(curr_pos=np.array([0,0,0]))

    env = LongTrajEnv(
        waypoints = square_wpts,
        base_env = get_env(wind_ranges = wind_range , **env_kwargs),
        initial_waypoints = square_np,
        randomize_direction=False
    )

    return env

# %%
# Evaluates all saved agents with their params on a wind range
def evaluate_agents(agents, params, wind_range):
    logs = []
    
    for agent, param in tqdm(zip(agents, params), total=len(agents)):
        if agent == 'pid':
            param = {
                'steps_u': 1,
                'scaling_factor': 1,
                'bounding_rect_length': 100
            }

        env = get_long_env(param, wind_range)
        done = False
        state = env.reset()
        log = DataLog(env.base_env.vehicle, env.base_env.ctrl,
                          other_vars=('reward',))
        while not done:
            if agent == 'pid':
                action = [0,0,0]
            else:
                action = agent.predict(state, deterministic=True)[0]
                
            state, reward, done, info = env.step(action)
            log.log(reward=reward)
        
        log.done_logging()
        logs.append(log)

    return logs

# %%
study, cardinal_low, cardinal_params_low = get_study_agent_params('cardinal@random5m', overwrite_trial=63)
study, cardinal_high, cardinal_params_high = get_study_agent_params('cardinal@random5m')
study, north, north_params = get_study_agent_params('n@random5m')
study, cardinal_vel, cardinal_vel_params = get_study_agent_params('cardinal@vel')
# Out:
# [I 2023-08-24 20:14:13,612] Using an existing study with name 'cardinal@random5m' instead of creating a new one.
# [I 2023-08-24 20:14:15,172] Using an existing study with name 'cardinal@random5m' instead of creating a new one.
# [I 2023-08-24 20:14:15,276] Using an existing study with name 'n@random5m' instead of creating a new one.
# [I 2023-08-24 20:14:15,357] Using an existing study with name 'cardinal@vel' instead of creating a new one.

# %%
all_agents = ['pid', cardinal_low, cardinal_high, north, cardinal_vel]
all_params = [None, cardinal_params_low, cardinal_params_high, north_params, cardinal_vel_params]

# %%
logs = evaluate_agents(all_agents, all_params, [(0,0), (0,0), (0,0)])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plt.title("No Wind Trajectories")
plt.plot(logs[0].x, logs[0].y, label='PID', alpha=0.5)
plt.plot(logs[1].x, logs[1].y, label='Cardinal Low', alpha=0.5)
plt.plot(logs[2].x, logs[2].y, label='Cardinal High', alpha=0.5)
plt.plot(logs[3].x, logs[3].y, label='North', alpha=0.5)
plt.scatter(logs[0].target.position[:,0], logs[0].target.position[:,1], marker='x', color="red")
plt.legend(loc='upper right')
plt.xlim(-20, 180)
plt.xlabel("X (m)")
plt.ylabel("Y (m)")
plt.show()

# %%
n5_logs = evaluate_agents(all_agents, all_params, [(0,0), (5,5), (0,0)])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plt.title("N 5m/s Trajectories")
plt.plot(n5_logs[0].x, n5_logs[0].y, label='PID', alpha=0.5)
plt.plot(n5_logs[1].x, n5_logs[1].y, label='Cardinal Low', alpha=0.5)
plt.plot(n5_logs[2].x, n5_logs[2].y, label='Cardinal High', alpha=0.5)
plt.plot(n5_logs[3].x, n5_logs[3].y, label='North', alpha=0.5)
plt.scatter(n5_logs[0].target.position[:,0], n5_logs[0].target.position[:,1], marker='x', color="red")
plt.legend(loc='upper right')
plt.xlim(-20, 180)
plt.xlabel("X (m)")
plt.ylabel("Y (m)")
plt.show()

# %%
w7_logs = evaluate_agents(all_agents, all_params, [(-7,-7), (0,0), (0,0)])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plt.title("W 7m/s Trajectories")
plt.plot(w7_logs[0].x, w7_logs[0].y, label='PID', alpha=0.5)
plt.plot(w7_logs[1].x, w7_logs[1].y, label='Cardinal Low', alpha=0.5)
plt.plot(w7_logs[2].x, w7_logs[2].y, label='Cardinal High', alpha=0.5)
plt.plot(w7_logs[3].x, w7_logs[3].y, label='North', alpha=0.5)
plt.scatter(w7_logs[0].target.position[:,0], w7_logs[0].target.position[:,1], marker='x', color="red")
plt.legend(loc='upper left')
plt.xlim(-100, 110)
plt.xlabel("X (m)")
plt.ylabel("Y (m)")
plt.show()

# %% [markdown]
# ## Reward Bonus Experiment

# %%
study, high_reward_agent, high_reward_params = get_study_agent_params('cardinal@random5mHigherBonus')
# Out:
# [I 2023-08-15 13:10:44,972] Using an existing study with name 'cardinal@random5mHigherBonus' instead of creating a new one.

# %%
study, low_reward_agent, low_reward_params = get_study_agent_params('cardinal@random5mNoBonus')
# Out:
# [I 2023-08-15 13:10:46,952] Using an existing study with name 'cardinal@random5mNoBonus' instead of creating a new one.

# %%
extra_agents = all_agents + [high_reward_agent, low_reward_agent]
extra_params = all_params + [high_reward_params, low_reward_params]

# %%
se10_logs = evaluate_agents(extra_agents, extra_params, [(-7.07106781,-7.07106781), (7.07106781,7.07106781), (0,0)])
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots()
plt.title("NW 10 m/s Trajectories Under Varying Waypoint Bonus") # seems like this was a typo in the paper, will correct before next version, but conclusions hold
plt.plot(se10_logs[2].x, se10_logs[2].y, label='1500 Bonus', alpha=0.5)
plt.plot(se10_logs[4].x, se10_logs[4].y, label='7500 Bonus', alpha=0.5)
plt.plot(se10_logs[5].x, se10_logs[5].y, label='No Bonus', alpha=0.5)
plt.scatter(se10_logs[0].target.position[:,0], se10_logs[0].target.position[:,1], marker='x', color="red")

plt.xlim(-10, 190)
plt.ylim(-20, 120)
plt.xlabel("X (m)")
plt.ylabel("Y (m)")

box_size = 100

# Plot the dotted lines
offset = 5  # 5m offset from the inside of the box
top_line_inside = plt.Line2D([offset, box_size - offset], [box_size - offset, box_size - offset], linestyle='dotted', color='red')
top_line_outside = plt.Line2D([offset, box_size - offset], [box_size+offset, box_size+offset], linestyle='dotted', color='red')
ax.add_line(top_line_inside)
ax.add_line(top_line_outside)

# Right side lines
right_line_inside = plt.Line2D([box_size - offset, box_size - offset], [offset, box_size - offset], linestyle='dotted', color='red')
right_line_outside = plt.Line2D([box_size + offset, box_size + offset], [offset, box_size - offset], linestyle='dotted', color='red')
ax.add_line(right_line_inside)
ax.add_line(right_line_outside)

# Bottom side lines
bottom_line_inside = plt.Line2D([offset, box_size - offset], [offset, offset], linestyle='dotted', color='red')
bottom_line_outside = plt.Line2D([offset, box_size - offset], [0-offset, 0-offset], linestyle='dotted', color='red')
ax.add_line(bottom_line_inside)
ax.add_line(bottom_line_outside)

# Left side lines
left_line_inside = plt.Line2D([offset, offset], [offset, box_size - offset], linestyle='dotted', color='red')
left_line_outside = plt.Line2D([0-offset, 0-offset], [offset, box_size - offset], linestyle='dotted', color='red', label='Safety Corridor')
ax.add_line(left_line_inside)
ax.add_line(left_line_outside)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Plot of Rewards Across Multiple Wind Speeds
# You can just load in the appropriate np arrays that are commented out using `np.load()` if you do not want to wait for these experiments to finish.

# %%
n_winds = [
    [(0,0),(1,1),(0,0)],
    [(0,0),(2,2),(0,0)],
    [(0,0),(3,3),(0,0)],
    [(0,0),(4,4),(0,0)],
    [(0,0),(5,5),(0,0)],
    [(0,0),(6,6),(0,0)],
    [(0,0),(7,7),(0,0)],
    [(0,0),(8,8),(0,0)],
    [(0,0),(9,9),(0,0)],
    [(0,0),(10,10),(0,0)],
    [(0,0),(11,11),(0,0)],
    [(0,0),(12,12),(0,0)],
]

# %%
e_winds = [
    [(1,1),(0,0),(0,0)],
    [(2,2),(0,0),(0,0)],
    [(3,3),(0,0),(0,0)],
    [(4,4),(0,0),(0,0)],
    [(5,5),(0,0),(0,0)],
    [(6,6),(0,0),(0,0)],
    [(7,7),(0,0),(0,0)],
    [(8,8),(0,0),(0,0)],
    [(9,9),(0,0),(0,0)],
    [(10,10),(0,0),(0,0)],
    [(11,11),(0,0),(0,0)],
    [(12,12),(0,0),(0,0)],
]

# %%
sw_winds = [
  [(-0.707, -0.707), (-0.707, -0.707), (0, 0)],  # 1 m/s
  [(-1.414, -1.414), (-1.414, -1.414), (0, 0)],  # 2 m/s
  [(-2.121, -2.121), (-2.121, -2.121), (0, 0)],  # 3 m/s
  [(-2.828, -2.828), (-2.828, -2.828), (0, 0)],  # 4 m/s
  [(-3.536, -3.536), (-3.536, -3.536), (0, 0)],  # 5 m/s
  [(-4.243, -4.243), (-4.243, -4.243), (0, 0)],  # 6 m/s
  [(-4.950, -4.950), (-4.950, -4.950), (0, 0)],  # 7 m/s
  [(-5.657, -5.657), (-5.657, -5.657), (0, 0)],  # 8 m/s
  [(-6.364, -6.364), (-6.364, -6.364), (0, 0)],  # 9 m/s
  [(-7.071, -7.071), (-7.071, -7.071), (0, 0)],  # 10 m/s
  [(-7.778, -7.778), (-7.778, -7.778), (0, 0)],  # 11 m/s
  [(-8.485, -8.485), (-8.485, -8.485), (0, 0)],  # 12 m/s
]

# %%
# Evaluates all agents on all winds
def evaluate_all_winds(agents, params, wind_ranges):
    rewards = []
    for wind_range in tqdm(wind_ranges):
        logs = evaluate_agents(agents, params, wind_range)
        wind_reward = []
        for log in logs:
            wind_reward.append(np.sum(log.reward))

        rewards.append(wind_reward)

    return np.array(rewards)

# %%
north_rewards = evaluate_all_winds(all_agents, all_params, n_winds)
# Out:
# ...
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
np.save('./data/wind_mag_rewards_north.npy', north_rewards) # can load this in to skip waiting

# %%
plt.figure(figsize=(10, 4))
x_data = list(range(1,north_rewards.shape[0]+1))
plt.title("Wind Magnitude (North) Impact on Rewards")

plt.plot(x_data, north_rewards[:,0], label='PID', alpha=0.25, color='blue')
plt.scatter(x_data, north_rewards[:,0], alpha=0.5, color='blue', marker='o')

plt.plot(x_data, north_rewards[:,1], label='RL Cardinal Low', alpha=0.25, color='red')
plt.scatter(x_data, north_rewards[:,1], alpha=0.5, color='red', marker='x')

plt.plot(x_data, north_rewards[:,2], label='RL Cardinal High', alpha=0.25, color='purple')
plt.scatter(x_data, north_rewards[:,2], alpha=0.5, color='purple', marker='+')

plt.plot(x_data, north_rewards[:,3], label='RL North', alpha=0.25, color='green')
plt.scatter(x_data, north_rewards[:,3], alpha=0.5, color='green', marker='^')

plt.plot(x_data, north_rewards[:,4], label='Cardinal Vel', alpha=0.25, color='orange')
plt.scatter(x_data, north_rewards[:,4], alpha=0.5, color='orange', marker='v')

plt.xlabel("Wind Magnitude (m/s)")
plt.ylabel("Reward")
plt.xticks(x_data)
plt.legend()

# %%
sw_rewards = evaluate_all_winds(all_agents, all_params, sw_winds)

# %%
np.save('wind_mag_rewards_southwest.npy', sw_rewards) # can load this in to skip waiting

# %%
plt.figure(figsize=(10, 4))
x_data = list(range(1,sw_rewards.shape[0]+1))
plt.title("Wind Magnitude (South West) Impact on Rewards")

plt.plot(x_data, sw_rewards[:,0], label='PID', alpha=0.25, color='blue')
plt.scatter(x_data, sw_rewards[:,0], alpha=0.5, color='blue', marker='o')

plt.plot(x_data, sw_rewards[:,1], label='RL Cardinal Low', alpha=0.25, color='red')
plt.scatter(x_data, sw_rewards[:,1], alpha=0.5, color='red', marker='x')

plt.plot(x_data, sw_rewards[:,2], label='RL Cardinal High', alpha=0.25, color='purple')
plt.scatter(x_data, sw_rewards[:,2], alpha=0.5, color='purple', marker='+')

plt.plot(x_data, sw_rewards[:,3], label='RL North', alpha=0.25, color='green')
plt.scatter(x_data, sw_rewards[:,3], alpha=0.5, color='green', marker='^')

plt.plot(x_data, sw_rewards[:,4], label='Cardinal Vel', alpha=0.25, color='orange')
plt.scatter(x_data, sw_rewards[:,4], alpha=0.5, color='orange', marker='v')

plt.xlabel("Wind Magnitude (m/s)")
plt.ylabel("Reward")
plt.xticks(x_data)
plt.legend()

# %%
e_rewards = evaluate_all_winds(all_agents, all_params, e_winds)

# %%
np.save('wind_mag_rewards_east.npy', e_rewards) # can load this to skip waiting

# %%
plt.figure(figsize=(10, 4))
x_data = list(range(1,e_rewards.shape[0]+1))
plt.title("Wind Magnitude (East) Impact on Rewards")

plt.plot(x_data, e_rewards[:,0], label='PID', alpha=0.25, color='blue')
plt.scatter(x_data, e_rewards[:,0], alpha=0.5, color='blue', marker='o')

plt.plot(x_data, e_rewards[:,1], label='RL Cardinal Low', alpha=0.25, color='red')
plt.scatter(x_data, e_rewards[:,1], alpha=0.5, color='red', marker='x')

plt.plot(x_data, e_rewards[:,2], label='RL Cardinal High', alpha=0.25, color='purple')
plt.scatter(x_data, e_rewards[:,2], alpha=0.5, color='purple', marker='+')

plt.plot(x_data, e_rewards[:,3], label='RL North', alpha=0.25, color='green')
plt.scatter(x_data, e_rewards[:,3], alpha=0.5, color='green', marker='^')

plt.plot(x_data, e_rewards[:,4], label='Cardinal Vel', alpha=0.25, color='orange')
plt.scatter(x_data, e_rewards[:,4], alpha=0.5, color='orange', marker='v')

plt.xlabel("Wind Magnitude (m/s)")
plt.ylabel("Reward")
plt.xticks(x_data)
plt.legend()

# %% [markdown]
# ## Real Trajectory
#
# How do our models perform on real trajectories?

# %%
def get_real_env(best_params, wind_range):
    env_kwargs = dict(
        safety_radius=5,
        seed=0,
        get_controller_fn=lambda m: get_established_controller(m),
        vp = VP,
    )

    env_kwargs['steps_u'] = best_params['steps_u']
    env_kwargs['scaling_factor'] = best_params['scaling_factor']

    nasa_wp = np.asarray([ # defines a real trajectory shown in a NASA paper
        [164.0146725649829, -0.019177722744643688, 0],
        [165.6418055187678, 111.5351051245816, 0],
        [127.3337449710234, 165.73576059611514, 0],
        [-187.28170707810204, 170.33217775914818, 0],
        [-192.03130502498243, 106.30660058604553, 0],
        [115.89920266153058, 100.8644210617058, 0],
        [114.81859536317643, 26.80923518165946, 0],
        [-21.459931490011513, 32.60508110653609, 0]
    ])
    
    real_traj = Trajectory(None, points=nasa_wp, resolution=best_params['bounding_rect_length']) 
    real_wpts = real_traj.generate_trajectory(curr_pos=np.array([0,0,0]))

    env = LongTrajEnv(
        waypoints = real_wpts,
        base_env = get_env(wind_ranges = wind_range , **env_kwargs),
        initial_waypoints = nasa_wp,
        randomize_direction=False
    )

    return env

# %%
def evaluate_agents_real(agents, params, wind_range):
    logs = []
    
    for agent, param in tqdm(zip(agents, params), total=len(agents)):
        if agent == 'pid':
            param = {
                'steps_u': 1,
                'scaling_factor': 1,
                'bounding_rect_length': 100
            }

        env = get_real_env(param, wind_range)
        done = False
        state = env.reset()
        log = DataLog(env.base_env.vehicle, env.base_env.ctrl,
                          other_vars=('reward',))
        while not done:
            if agent == 'pid':
                action = [0,0,0]
            else:
                action = agent.predict(state, deterministic=True)[0]
                
            state, reward, done, info = env.step(action)
            log.log(reward=reward)
        
        log.done_logging()
        logs.append(log)

    return logs

# %%
real_logs = evaluate_agents_real(all_agents, all_params, [(0,0),(0,0),(0,0)])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plt.title("Real Trajectory 0 m/s")
plt.plot(real_logs[0].x, real_logs[0].y, label='PID', alpha=0.5)
plt.plot(real_logs[1].x, real_logs[1].y, label='Cardinal Low', alpha=0.5)
plt.plot(real_logs[2].x, real_logs[2].y, label='Cardinal High', alpha=0.5)
plt.plot(real_logs[3].x, real_logs[3].y, label='North', alpha=0.5)
plt.scatter(real_logs[0].target.position[:,0], real_logs[0].target.position[:,1], marker='x', color="red")
plt.legend(loc='lower left')
# plt.xlim(-100, 110)
plt.xlabel("X (m)")
plt.ylabel("Y (m)")
plt.show()

# %%
real_logs_5m = evaluate_agents_real(all_agents, all_params, [(0,0),(5,5),(0,0)])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plt.title("Real Trajectory N 5 m/s")
plt.plot(real_logs_5m[0].x, real_logs_5m[0].y, label='PID', alpha=0.5)
plt.plot(real_logs_5m[1].x, real_logs_5m[1].y, label='Cardinal Low', alpha=0.5)
plt.plot(real_logs_5m[2].x, real_logs_5m[2].y, label='Cardinal High', alpha=0.5)
plt.plot(real_logs_5m[3].x, real_logs_5m[3].y, label='North', alpha=0.5)
plt.scatter(real_logs_5m[0].target.position[:,0], real_logs_5m[0].target.position[:,1], marker='x', color="red")
plt.legend(loc='lower left')
# plt.xlim(-100, 110)
plt.xlabel("X (m)")
plt.ylabel("Y (m)")
plt.show()

# %%
real_logs_10m = evaluate_agents_real(all_agents, all_params, [(-7.071, -7.071), (-7.071, -7.071), (0, 0)])
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
plt.title("Real Trajectory SW 10 m/s")
plt.plot(real_logs_10m[0].x, real_logs_10m[0].y, label='PID', alpha=0.5)
plt.plot(real_logs_10m[1].x, real_logs_10m[1].y, label='Cardinal Low', alpha=0.5)
plt.plot(real_logs_10m[2].x, real_logs_10m[2].y, label='Cardinal High', alpha=0.5)
plt.plot(real_logs_10m[3].x, real_logs_10m[3].y, label='North', alpha=0.5)
plt.scatter(real_logs_5m[0].target.position[:,0], real_logs_5m[0].target.position[:,1], marker='x', color="red")
plt.legend(loc='lower left')
# plt.xlim(-100, 110)
plt.xlabel("X (m)")
plt.ylabel("Y (m)")
plt.show()
